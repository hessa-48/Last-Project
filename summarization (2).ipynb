# %% [markdown]
# using google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# Then load your file from Drive
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##summariaztion model

# %%
# Install and import
# !pip install --upgrade openai
import pandas as pd
from collections import defaultdict
from openai import OpenAI

# Load the data
df = pd.read_csv('/content/drive/MyDrive/cleaned_reviews.csv')  # Adjust path if needed

# Step 1: Convert to structured review data
def convert_df_to_json(df):
    grouped_data = defaultdict(lambda: {"reviews": [], "category": ""})

    for _, row in df.iterrows():
        product = row.get('name')
        category = str(row.get('categories')).split(',')[0] if pd.notnull(row.get('categories')) else "Misc"
        review_text = row.get('reviews.text')
        rating = row.get('reviews.rating')

        if pd.notnull(review_text) and pd.notnull(rating):
            grouped_data[product]["reviews"].append({
                "text": str(review_text),
                "rating": float(rating)
            })
            grouped_data[product]["category"] = category

    structured_reviews = []
    for product, details in grouped_data.items():
        if len(details["reviews"]) >= 2:
            ratings = [r["rating"] for r in details["reviews"]]
            texts = [r["text"] for r in details["reviews"]]

            structured_reviews.append({
                "product_name": product,
                "category": details["category"],
                "avg_rating": sum(ratings) / len(ratings),
                "top_pros": [t for t in texts if "good" in t.lower() or "great" in t.lower()][:2],
                "top_complaints": [t for t in texts if "bad" in t.lower() or "disappoint" in t.lower()][:2]
            })
    return structured_reviews

# Step 2: Group insights by category
def group_by_category(insights):
    category_map = defaultdict(list)
    for item in insights:
        category_map[item['category']].append(item)
    return category_map

# Step 3: Build insight string for GPT
def build_insight_string(products):
    sorted_products = sorted(products, key=lambda x: x["avg_rating"], reverse=True)
    top_3 = sorted_products[:3]
    worst = sorted_products[-1]

    insights_str = ""
    for idx, p in enumerate(top_3, 1):
        insights_str += f"""{idx}. {p['product_name']} - Rating: {p['avg_rating']:.2f}
Key Pros: {", ".join(p['top_pros']) or "N/A"}
Top Complaints: {", ".join(p['top_complaints']) or "N/A"}\n\n"""

    insights_str += f"Worst Product:\n{worst['product_name']} - Rating: {worst['avg_rating']:.2f}\n"
    insights_str += f"Complaints: {', '.join(worst['top_complaints']) or 'N/A'}"

    return insights_str

# Step 4: GPT-4 article generation
client = OpenAI(api_key="my key")

def generate_article(category, insights):
    prompt = f"""
You are a professional tech writer.

Write a clear, structured summary about the product category: "{category}".

The summary should include:
1. Top 3 products in this category and their key differences.
2. Top complaints for each of those top 3 products.
3. The worst product and why users should avoid it.

Make it professional, insightful, and easy to read — no bullet points or lists.

Here are the insights to use:
{insights}

Now write the article.
"""
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7,
        max_tokens=900
    )
    return response.choices[0].message.content

# Step 5: Run for each category
structured = convert_df_to_json(df)
grouped = group_by_category(structured)

for category, products in grouped.items():
    if len(products) < 2:
        continue  # Skip if not enough products in the category

    insights = build_insight_string(products)
    article = generate_article(category, insights)

    print(f"\n{'='*80}\n📘 Category: {category}\n{'='*80}\n")
    print(article)
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.74.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
#
# ================================================================================
# 📘 Category: E-Readers & Home
# ================================================================================
#
# In the product category of "E-Readers & Home", a variety of items are available that cater to different needs and uses in both professional and personal settings. The top three products in this category have been identified, along with their key differences, top complaints, and a product that users should avoid.
#
# The Expanding Accordion File Folder Plastic Portable Document Organizer Letter Size is a standout product with a perfect rating of 5.00. Its key feature is its expandability, which provides a practical solution for organizing files in one compact and portable system. Users commend the product for its high-quality material and cost-effectiveness, alongside its portability, making it a recommended choice for those seeking an efficient and reliable document organizer. Remarkably, there have been no recorded complaints about this product, signifying a high level of customer satisfaction.
#
# Secondly, the AmazonBasics AAA Performance Alkaline Batteries (36 Count) holds a rating of 4.40. Users appreciate these batteries for their longevity and value for money. The convenience of purchasing and having these batteries delivered directly to one's home is another factor that contributes to their popularity. However, there have been complaints regarding the quality of some batteries in the set. One user reported a missing backup spring which necessitated a makeshift solution for the battery to function. Additionally, some users have expressed disappointment with the batteries’ lifespan, stating they do not last as long as other brand-name batteries.
#
# Interestingly, the AmazonBasics AAA Performance Alkaline Batteries (36 Count) is also the product that users should avoid. Despite its overall rating of 4.40, the aforementioned complaints reflect inconsistencies in the product's quality. Users have cited issues with the battery's components and longevity, which can lead to inconveniences and potential additional costs. Therefore, despite its advantages and affordability, the product's inconsistencies make it a less reliable choice compared to other batteries available in the market.
#
# In conclusion, while the Expanding Accordion File Folder Plastic Portable Document Organizer Letter Size stands out as a highly recommended product in the "E-Readers & Home" category, the AmazonBasics AAA Performance Alkaline Batteries (36 Count) has shown that even a high rating does not exempt a product from having significant flaws. This emphasizes the importance of considering both the pros and cons when selecting a product to ensure it meets the user's specific needs and expectations.
#
# ================================================================================
# 📘 Category: electronics
# ================================================================================
#
# In the world of electronics, consumers are often overwhelmed with the variety and complexity of available products. However, a few standout items have managed to rise above the rest in terms of functionality and user satisfaction. These include the Amazon Echo, the Fire TV Stick Streaming Media Player Pair Kit, and the AmazonBasics USB 3.0 Cable.
#
# The Amazon Echo is a top-tier product in this category, boasting a perfect rating. Its unique selling point lies within its intelligent personal assistant feature, Alexa, that responds to voice commands, plays music, provides weather updates, and even controls smart home devices. However, it's important to note that, as of now, there have been no reported complaints about this product.
#
# Similarly, the Fire TV Stick Streaming Media Player Pair Kit has also achieved a perfect rating. This device provides a plethora of streaming options, allowing users to access over 450+ channels for a monthly subscription fee. It also offers the added convenience of being operable via ethernet, ensuring no lag and uninterrupted streaming. However, one downside is the initial setup difficulty, especially for TVs where HDMI ports don't extend out, making the device challenging to install.
#
# The AmazonBasics USB 3.0 Cable is another top-rated product. Its key advantage is its length, which provides users with more flexibility in arranging their devices. It's also praised for its high-quality performance and its affordability as an AmazonBasics product. As with the previous products, there have been no complaints reported for this item.
#
# While these products have garnered high praise, the Oem Amazon Kindle Power USB Adapter Wall Travel Charger Fire/DX/+Micro USB Cable has been deemed the worst product in the electronics category. It holds a disappointing rating of 1.00, indicating a significantly lower level of user satisfaction. Unfortunately, details about the specific complaints concerning this product are not available at this time. However, the low rating suggests that consumers may encounter issues with either its performance or durability. Therefore, consumers are advised to avoid this product and opt for alternatives with higher ratings and more positive feedback.
#
# In conclusion, the Amazon Echo, the Fire TV Stick Streaming Media Player Pair Kit, and the AmazonBasics USB 3.0 Cable are currently the top three products in the electronics category. However, users should steer clear of the Oem Amazon Kindle Power USB Adapter Wall Travel Charger Fire/DX/+Micro USB Cable due to its low rating and potential issues.
#
# ================================================================================
# 📘 Category: best purchase
# ================================================================================
#
# The "best purchase" product category provides a wide range of high-quality items that offer great value for money. Among the top three products in this category, each has its unique attributes that set it apart from the others, yet they all share the common characteristic of providing good value at affordable prices.
#
# The Cat Litter Box Covered Tray Kitten Extra Large Enclosed Hooded Hidden Toilet ranks highest with a perfect 5-star rating. This product is particularly well-received by users for its great price and excellent value. The product has not received any significant complaints, which further attests to its superior quality and durability.
#
# The second product in this category is the AmazonBasics AA Performance Alkaline Batteries, which boasts a respectable rating of 4.42 stars. The product is praised for its good price and quick delivery, but some users have reported issues with its longevity. A few have expressed disappointment with the battery's performance, claiming that it doesn't last as long in some devices compared to other brands.
#
# The third product is the AmazonBasics Double-Door Folding Metal Dog Crate with a rating of 3.50 stars. Despite its noticeably lower rating than the other two products, it still offers good value for the price. However, one user did report receiving a tilted crate, which, although not drastic, seemed to have affected the overall rating.
#
# Whilst these top three products all provide value and quality, there is one product that users should steer clear of in this category. The AmazonBasics Double-Door Folding Metal Dog Crate, despite being one of the top three, also falls into the worst product category. Its rating of 3.50 stars is the lowest among the top products, and although it has no specific complaints listed, the lower rating suggests that this product might not meet the expectations of all users, making it less desirable compared to the other products.
#
# In conclusion, the best purchase category offers a range of products that offer great value for money. While each product has its unique strengths and minor setbacks, they all maintain a standard of quality that is reflected in their overall ratings. However, users should exercise caution when considering the AmazonBasics Double-Door Folding Metal Dog Crate due to its lower rating.
#
# ================================================================================
# 📘 Category: Online offers
# ================================================================================
#
# In the realm of online offers, three products have emerged as front-runners, each with their unique strengths and weaknesses.
#
# The All-New Fire HD 8 Tablet with Alexa, 32 GB, Marine Blue, is a favorite amongst users, boasting a respectable 4.60 rating. This device has won praise for being a great buy, especially for children, and is lauded for its user-friendly interface and powerful performance. However, there are significant complaints about its durability, with some users reporting that the tablets stopped charging shortly after purchase. Additionally, dissatisfaction with customer service after attempting to address these issues has also been noted.
#
# The Fire HD 10 Tablet, Silver Aluminum, is another popular choice with a 4.59 rating. This tablet is highly regarded as a more affordable alternative to an iPad, offering similar, if not better, quality. Despite its popularity, users have voiced concerns about the device's battery life, which appears to be a common issue with many tablets in the market.
#
# The All-New Fire HD 8 Tablet, 16 GB, Black, rounds out the top three with a 4.58 rating. Users appreciate its quick and responsive performance, even in comparison to the slightly larger 7" Fire. However, the lack of access to Google Play Store apps has been a point of contention for some users, although a workaround is available. Additionally, some users were dissatisfied with the device's screen brightness and camera quality.
#
# Despite these top contenders, the All-New Fire HD 8 Tablet, 16 GB, Blue, is considered the worst product in this category with a rating of 4.52. The primary complaint is the device's reliability, with reports of the tablet crashing and failing to turn on shortly after being set up. This issue, combined with the disappointment it caused, particularly for younger users, makes this product one to be wary of when considering a purchase.
#
# In conclusion, while the All-New Fire HD 8 Tablet with Alexa, 32 GB, Marine Blue, and the Fire HD 10 Tablet, Silver Aluminum, stand out in terms of user satisfaction and performance, it's crucial to consider the reported drawbacks before making a purchase. Furthermore, the All-New Fire HD 8 Tablet, 16 GB, Blue is advised to be avoided due to issues with reliability.
#
# ================================================================================
# 📘 Category: For Kids
# ================================================================================
#
# In the product category "For Kids," three top-tier products have been identified based on their overall ratings and user feedback. These include the All-New Fire HD 8 Kids Edition Tablet in Pink and Blue Kid-Proof Case, and the Fire Kids Edition Tablet with 7-inch Display in Blue Kid-Proof Case.
#
# The All-New Fire HD 8 Kids Edition Tablet in Pink Kid-Proof Case, with a rating of 4.64, is praised by users for its educational value. Parents and grandparents have found it to be a beneficial tool in teaching children shapes, basic colors, words, puzzles, numbers, sorting, and sequencing. However, it does have its drawbacks. Complaints include a limited selection of apps and games, with popular ones like YouTube kids being notably absent. Some parents have also highlighted the need to pre-download items for offline use.
#
# Its counterpart, the All-New Fire HD 8 Kids Edition Tablet in Blue Kid-Proof Case, shares a similar rating of 4.63. The product's pros and cons are similar to its pink variant. Users have praised the tablet's educational value and the effective parental controls but have expressed disappointment with the sluggish navigation and unresponsive touchscreen. Some users also reported receiving faulty units that wouldn't turn on, adding to the list of complaints.
#
# The Fire Kids Edition Tablet with a 7-inch display in Blue Kid-Proof Case, has a rating of 4.54. This tablet is favored for its affordable price and 2-year warranty, making it a great budget option for streaming Netflix. However, users have expressed dissatisfaction with the Amazon lock-in, which prevents compatibility with the Google Play Store and limits the availability of popular children's games.
#
# Despite these top-rated products, not all kid-friendly tablets have fared as well. The Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case has the lowest rating of 4.53. Users have reported significant issues, particularly for children with learning disabilities. For example, to access audible.com for a dyslexic child, parents had to disable many of the family-friendly features, reducing the product's overall utility. Some parents also found it concerning that children could have full access to Alexa and shopping features.
#
# In conclusion, while the Fire HD 8 Kids Edition Tablets and the Fire Kids Edition Tablet with a 7-inch display have their merits and drawbacks, they stand out as the top products in the "For Kids" category. Users should, however, be aware of potential limitations in app availability and compatibility with non-Amazon services. As for the Fire Kids Edition Tablet with a 7-inch display in Pink Kid-Proof Case, users should be cautious due to its limitations for children with learning disabilities and unrestricted access to potentially inappropriate features.
#
# ================================================================================
# 📘 Category: Voice-Enabled Tab
# ================================================================================
#
# In the realm of voice-enabled tablets, three prominent products have emerged: the Fire HD 8 Tablet with Alexa, featuring an 8 HD Display and 16 GB capacity in Tangerine color, and its counterpart with a larger 32 GB capacity, both offering special offers.
#
# The 16 GB model, boasting an impressive rating of 4.60, is praised for its speed and responsiveness, making it ideal for light web browsing, catching up on emails, or simply as an entertainment device. Its compatibility with Amazon's Alexa enhances the user experience, creating a seamless integration of technology into daily life. However, some users have expressed disappointment over its limited app availability due to its non-compatibility with the Google Play Store. Although this issue can be resolved with a quick online search, it remains a notable drawback.
#
# The 32 GB model, with a slightly lower rating of 4.59, is similarly lauded for its video quality and suitability for reading and gaming. Yet it shares the same issue as the 16 GB model, disappointing users with a limited selection of apps. This is especially frustrating for users who are familiar with the extensive app libraries of other Android devices.
#
# Although the Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB model shares a lot of positive aspects with its 16 GB counterpart, it is considered the worst product of the two due to its inability to meet user expectations in terms of app availability. Additionally, some users have noted that its operating system, while based on Android, lacks the customization options that many Android users appreciate. This, coupled with its limited app selection, has led to some dissatisfaction among users.
#
# In conclusion, while both the 16 GB and 32 GB models of the Fire HD 8 Tablet with Alexa offer a plethora of features and conveniences, they are not without their flaws. It is essential that potential users consider these factors when deciding which tablet to purchase. The 16 GB model is suitable for users who prioritize speed and responsiveness, while the 32 GB model is ideal for those who require more storage capacity. However, both models may disappoint users who desire a wide selection of apps and customization options.
